# %%
import os
# !rm -rf /content/Navier_Stokes_Exploration_with_PINNs

# %%
# %cd /content

# %%
# !pwd

# %%
import os
if not os.path.exists('Navier_Stokes_Exploration_with_PINNs'):
  # !git clone -b branch_name https://github.com/deveshshah1/Navier_Stokes_Exploration_with_PINNs.git
else:
  print('Repository already cloned.')

# %%
# %cd Navier_Stokes_Exploration_with_PINNs/

# %%
# !uv python install 3.11
# !uv venv /content/venv --python 3.11
# !uv pip install -r requirements.txt --python /content/venv --index-strategy unsafe-best-match

# %%
import os
os.environ["WANDB_API_KEY"] = "wandb_XXXXXXXX"

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !/content/venv/bin/python ./PINNs_Modeling/train.py
